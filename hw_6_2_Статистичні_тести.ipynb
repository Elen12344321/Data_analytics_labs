# %% [markdown]
# ## Домашнє завдання 6: Статистичні тести

# %% [markdown]
# 0. Зчитайте дані з `data.csv` та запишіть значення колонки data у форматі np.ndarray в змінну data. Ми будемо далі працювати з цією змінною.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/python_labs/chapter 6/data.csv')

data = df['data'].to_numpy()

print(data[:10])
# Out:
# [17.49945292 19.66239904  7.18282343 29.84162485  9.23938649 14.94951581
#  23.0172885  12.52827148 13.65228669 14.54595431]

# %% [markdown]
# Запустіть код нижче. Для коректної робити всіх подальших методів дані мають бути у вигляді одновимірного вектора, тобто мати розмір (100,).

# %%
print("Розмір масиву:", data.shape)

if data.ndim == 1 and data.shape[0] == 100:
    print("Масив є одновимірним і має правильний розмір.")
else:
    print("Помилка: масив має неправильний розмір або не є одновимірним.")

print("Перші 10 значень масиву:", data[:10])
# Out:
# Розмір масиву: (100,)
# Масив є одновимірним і має правильний розмір.
# Перші 10 значень масиву: [17.49945292 19.66239904  7.18282343 29.84162485  9.23938649 14.94951581
#  23.0172885  12.52827148 13.65228669 14.54595431]

# %% [markdown]
# 1. Зчитані дані - це сума покупок в доларах наших покупців на сайті протягом липня 2022 року.
#
# До цього місяця, ми мали продажі в середньому на чек $20. Чи вийшло у нас статистично значущо **підвищити** середній чек за останній місяць?
#
# Оберіть статистичний тест (z-test чи t-test). Виведіть p-значення статистичного тесту та зробіть висновок, чи ми маємо зараз статистично значущу різницю у розмірі середнього чеку.
#
# **Підказка**: тут тест буде одновибірковий.

# %%
from scipy import stats

#Обираємо z-test
mu = 20  # Середній чек до липня 2022 року
alpha = 0.05  # Рівень значущості

sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # ddof=1 для обчислення стандартного відхилення вибірки
n = len(data)  # Розмір вибірки

z = (sample_mean - mu) / (sample_std / np.sqrt(n))

p_value = 1 - stats.norm.cdf(z)

print("Середнє значення вибірки:", sample_mean)
print("Стандартне відхилення вибірки:", sample_std)
print("Z-статистика:", z)
print("P-значення:", p_value)

print("Прийняття рішення на основі p-значення:")
if p_value < alpha:
    print("Ми маємо статистично значущу різницю у розмірі середнього чеку.")
else:
    print("Ми не маємо статистично значущої різниці у розмірі середнього чеку.")
# Out:
# Середнє значення вибірки: 19.37755319670441
# Стандартне відхилення вибірки: 6.25356123240434
# Z-статистика: -0.995347738933505
# P-значення: 0.8402164165464012
# Прийняття рішення:
# Ми не маємо статистично значущої різниці у розмірі середнього чеку.

# %% [markdown]
# 2. Пройшов час, і ми зібрали дані про продажі за серпень 2022 року, які зберігли у файл `data_2.csv`. Продажів було дещо більше, але чи змінився стат. значущо середній чек порівняно з липнем 2022? Перевірте це використовуючи ztest.
#
#   Виведіть p-значення статистичного тесту та зробіть висновок, чи ми маємо зараз статистично значущу різницю у розмірі середнього чека між двома місяцями.
#
#   **Підказка**: треба провести двовибірковий ztest з Н0 - що середні значення в липні та серпні 2022 року - однакові. Для кращого розуміння ситуації, можливо вам буде цікаво переглянути, які середні показники чеку були в кожен з місяців. Порівняйте свій висновок з простого спостереження середніх значень і висновок статистичного тесту. Чи вони збігаються?

# %%
df_august = pd.read_csv('/content/drive/MyDrive/python_labs/chapter 6/data_2.csv')
data_august = df_august['data'].to_numpy()

mean_july = np.mean(data)
mean_august = np.mean(data_august)
std_july = np.std(data, ddof=1)
std_august = np.std(data_august, ddof=1)
n_july = len(data)
n_august = len(data_august)

z = (mean_july - mean_august) / np.sqrt((std_july**2 / n_july) + (std_august**2 / n_august))

p_value = 2 * (1 - stats.norm.cdf(abs(z)))

print("Середнє значення чеку за липень:", mean_july)
print("Середнє значення чеку за серпень:", mean_august)
print("Z-статистика:", z)
print("P-значення:", p_value)

print("Прийняття рішення на основі p-значення:")
alpha = 0.05
if p_value < alpha:
    print("Ми маємо статистично значущу різницю у розмірі середнього чеку.")
else:
    print("Ми не маємо статистично значущої різниці у розмірі середнього чеку.")
# Out:
# Середнє значення чеку за липень: 19.37755319670441
# Середнє значення чеку за серпень: 19.37322276512519
# Z-статистика: 0.005223803420073814
# P-значення: 0.9958320268584893
# Прийняття рішення на основі p-значення:
# Ми не маємо статистично значущої різниці у розмірі середнього чеку.

# %% [markdown]
# Висновок з простого спостереження середніх значень і висновок статистичного тесту збігаються, ми не маємо статистично значущої різниці у розмірі середнього чеку.
